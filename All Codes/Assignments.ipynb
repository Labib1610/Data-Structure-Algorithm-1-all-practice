# %% [markdown]
# # Assignment -1

# %% [markdown]
#     Insertion Sort for Descending Order

# %%
def insertion_sort(list):
    for i in range(1, len(list)):
        key = list[i]
        j = i - 1
        while j >= 0 and list[j] < key:
            list[j + 1] = list[j]
            j -= 1
        list[j + 1] = key

    return list

#For integer values
print(insertion_sort([5, 4, 7, 8, 9, 2, 1, 4, 5, 10, 3]))

# For string
x = ['c','r','z','a','f']
print(insertion_sort(x))
# Out:
# [10, 9, 8, 7, 5, 5, 4, 4, 3, 2, 1]
# ['z', 'r', 'f', 'c', 'a']

# %% [markdown]
# #Assignment - 2

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.link = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None

    # Defaulf Function For Further Use-1
    def insert_first(self, data):
        new_node = Node(data)
        new_node.link = self.head
        self.head = new_node

    # Defaulf Function For Further Use-2
    def insert_last(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        current = self.head
        while current.link is not None:
            current = current.link
        current.link = new_node

    # Defaulf Function For Further Use-3
    def delete_first(self):
        if self.head is None:
            print("The list is empty. Nothing to delete.")
            return
        temp = self.head
        self.head = self.head.link
        del temp

    # Defaulf Function For Further Use-4
    def delete_last(self):
        if self.head is None:
            print("The list is empty. Nothing to delete.")
            return
        elif self.head.link is None:
            del self.head
            self.head = None
            return
        current = self.head
        while current.link is not None and current.link.link is not None:
            current = current.link
        del current.link
        current.link = None

    # Question-1: Print the size of a linked list.
    def length(self):
      count = 0
      temp = self.head
      while temp is not None:
        count += 1
        temp = temp.link
      return count

    # Question-2: Given the head of a linked list, print the value of the middle node.
    def middle_node(self):
      if self.head is None:
          print("List is empty.")
          return None

      slow = self.head
      fast = self.head

      while fast is not None and fast.link is not None:
          slow = slow.link
          fast = fast.link.link

      print(f"Middle node data: {slow.data}")
      return slow

    # Question-3: Print the number of occurrences of a given number in a linked list.
    def number_of_occurrences(self, num):
      count = 0
      temp = self.head
      while temp is not None:
        if temp.data == num:
          count += 1
        temp = temp.link
      return count

    # Question-4: Given a sorted linked list, insert a number so that after insertion, it remains sorted.
    def insert_sorted(self, num):
      new_node = Node(num)
      if self.head is None or num < self.head.data:
          new_node.link = self.head
          self.head = new_node
          return
      current = self.head
      while current.link is not None and current.link.data < num:
          current = current.link
      new_node.link = current.link
      current.link = new_node
      return


    # Question-5: Delete all the even numbers from a linked list.
    def delete_even_valued_numbers(self):
      current = self.head
      prev = None
      while current is not None:
          if current.data % 2 == 0:
              if prev is not None:
                  prev.link = current.link
              else:
                  self.head = current.link
              del current
              current = prev.link
          else:
              prev = current
              current = current.link
      return

    # Question-7: Reverse a singly linked list.
    def reverse_list(self):
      new_list = SinglyLinkedList()
      current = self.head
      while current is not None:
          new_list.insert_first(current.data)
          current = current.link
      return new_list

    # Question-8: Given a singly linked list and an integer k, rotate the linked list to the left by k places.
    def rotate_list_k_integer(self, k):
      if self.head is None or k == 0:
          return
      tail = self.head
      while tail.link is not None:
        tail = tail.link # last node
      prev = None
      temp = self.head
      for i in range(k):
        prev = temp
        temp = temp.link
      prev.link = None
      tail.link = self.head
      self.head = temp
      return

    # Question-9: Given a singly linked list, print “YES” if it is a palindrome otherwise print “NO”.
    def is_palindrome(self):
      temp = self.head
      other = self.reverse_list().head
      while temp is not None:
        if temp.data != other.data:
          print("NO")
          return False
        temp = temp.link
        other = other.link
      print("YES")
      return True

    # Question-10: Given the head of a linked list, determine if the linked list has a cycle in it.
    def find_if_list_cycling(self):
      slow = self.head
      fast = self.head

      while fast is not None and fast.link is not None:
          slow = slow.link
          fast = fast.link.link

          if slow == fast:
              print("Cycle detected in the list.")
              return True

      print("No cycle found in the list.")
      return False

    def print_list(self):
        current = self.head
        print("Linked list:", end=" ")
        while current is not None:
            print(f"{current.data} ->", end=" ")
            current = current.link
        print("NULL")

# %%
sll = SinglyLinkedList()
for val in [1, 2, 3, 2, 4, 2]:
    sll.insert_last(val)

# Original list
print("Original list:")
sll.print_list()

# Question 1: Print size of linked list
print("\nQ1. Length of list:", sll.length())

# Question 2: Middle node
print("\nQ2. Middle node:")
sll.middle_node()

# Question 3: Occurrences of number 2
print("\nQ3. Occurrences of 2:", sll.number_of_occurrences(2))

# Question 4: Insert in sorted list
print("\nQ4. Insert 3.5 in sorted list:")
sll_sorted = SinglyLinkedList()
for val in [1, 2, 3, 4, 5]:
    sll_sorted.insert_last(val)
print("Before:")
sll_sorted.print_list()
sll_sorted.insert_sorted(3)
print("After:")
sll_sorted.print_list()

# Question 5: Delete even numbers
print("\nQ5. Delete even numbers:")
print("Before:")
sll.print_list()
sll.delete_even_valued_numbers()
print("After:")
sll.print_list()

# Reset for future tests
sll = SinglyLinkedList()
for val in [1, 2, 3, 2, 4, 2, 5]:
    sll.insert_last(val)

# Question 7: Reverse list
print("\nQ7. Reverse list:")
reversed_list = sll.reverse_list()
print("Original:")
sll.print_list()
print("Reversed:")
reversed_list.print_list()

# Question 8: Rotate list by k = 3
print("\nQ8. Rotate list by 3:")
print("Before:")
sll.print_list()
sll.rotate_list_k_integer(3)
print("After:")
sll.print_list()

# Question 9: Palindrome check
print("\nQ9. Palindrome check:")
palin_list = SinglyLinkedList()
for val in [1, 2, 3, 2, 1]:
    palin_list.insert_last(val)
palin_list.print_list()
palin_list.is_palindrome()

# Question 10: Cycle detection
print("\nQ10. Cycle detection:")
no_cycle_list = SinglyLinkedList()
for val in [1, 2, 3, 4, 5]:
    no_cycle_list.insert_last(val)
no_cycle_list.find_if_list_cycling()

# Create cycle manually for testing
cycle_node = SinglyLinkedList()
for val in [1, 2, 3, 4, 5]:
    cycle_node.insert_last(val)
tail = cycle_node.head
while tail.link:
    tail = tail.link
tail.link = cycle_node.head.link  # Creating a cycle (5 → 2)
print("Cycle list created.")
cycle_node.find_if_list_cycling()
# Out:
# Original list:
# Linked list: 1 -> 2 -> 3 -> 2 -> 4 -> 2 -> NULL
#
# Q1. Length of list: 6
#
# Q2. Middle node:
# Middle node data: 2
#
# Q3. Occurrences of 2: 3
#
# Q4. Insert 3.5 in sorted list:
# Before:
# Linked list: 1 -> 2 -> 3 -> 4 -> 5 -> NULL
# After:
# Linked list: 1 -> 2 -> 3 -> 3 -> 4 -> 5 -> NULL
#
# Q5. Delete even numbers:
# Before:
# Linked list: 1 -> 2 -> 3 -> 2 -> 4 -> 2 -> NULL
# After:
# Linked list: 1 -> 3 -> NULL
#
# Q7. Reverse list:
# Original:
# Linked list: 1 -> 2 -> 3 -> 2 -> 4 -> 2 -> 5 -> NULL
# Reversed:
# Linked list: 5 -> 2 -> 4 -> 2 -> 3 -> 2 -> 1 -> NULL
#
# Q8. Rotate list by 3:
# Before:
# Linked list: 1 -> 2 -> 3 -> 2 -> 4 -> 2 -> 5 -> NULL
# After:
# Linked list: 2 -> 4 -> 2 -> 5 -> 1 -> 2 -> 3 -> NULL
#
# Q9. Palindrome check:
# Linked list: 1 -> 2 -> 3 -> 2 -> 1 -> NULL
# YES
#
# Q10. Cycle detection:
# No cycle found in the list.
# Cycle list created.
# Cycle detected in the list.
# True

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def insert_first(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node

    # Question-6: Reverse a doubly linked list.
    def reverse_list(self):
        new_list = DoublyLinkedList()
        tail = self.head
        if tail is None:
          return new_list
        while tail.next is not None:
            new_list.insert_first(tail.data)
            tail = tail.next
        new_list.insert_first(tail.data)
        return new_list

    def print_list(self):
        current = self.head
        print("Doubly linked list:", end=" ")
        while current is not None:
            print(f"{current.data} <->", end=" ")
            current = current.next
        print("NULL")

# %%
dll = DoublyLinkedList()
for i in [1, 2, 3, 4, 5]:
    dll.insert_first(i)
dll.print_list()
# Reverse
dll2 = dll.reverse_list()
print("Reversed List:", end=" ")
dll2.print_list()
# Out:
# Doubly linked list: 5 <-> 4 <-> 3 <-> 2 <-> 1 <-> NULL
# Reversed List: Doubly linked list: 1 <-> 2 <-> 3 <-> 4 <-> 5 <-> NULL

# %% [markdown]
# # Assignment - 3

# %%
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None

    def insert(self, data):
        if self.root is None:
            self.root = TreeNode(data)
        else:
          Data = self.root
          while True:
            if data < Data.data:
              if Data.left is None:
                Data.left = TreeNode(data)
                break
              else:
                Data = Data.left
            else:
              if Data.right is None:
                Data.right = TreeNode(data)
                break
              else:
                Data = Data.right
        return
    def search(self, key):
        if self.root is None:
            return False
        current = self.root
        while current is not None:
            if key == current.data:
                return True
            elif key < current.data:
                current = current.left
            else:
                current = current.right
        return False
    def delete(self, key):
        if self.root is None:
            return False
        current = self.root
        parent = None
        while current is not None:
            if key == current.data:
                break
            elif key < current.data:
                parent = current
                current = current.left
            else:
                parent = current
                current = current.right
        if current is None:
            return False
        if current.left is None and current.right is None:
            if parent is None:
                self.root = None
            elif parent.left == current:
                parent.left = None
            else:
                parent.right = None
        elif current.left is None:
            if parent is None:
                self.root = current.right
            elif parent.left == current:
                parent.left = current.right
            else:
                parent.right = current.right
        elif current.right is None:
            if parent is None:
                self.root = current.left
            elif parent.left == current:
                parent.left = current.left
            else:
                parent.right = current.left

        else:
            successor_parent = current
            successor = current.right
            while successor.left:
                successor_parent = successor
                successor = successor.left
            current.data = successor.data
            if successor_parent.left == successor:
                successor_parent.left = successor.right
            else:
                successor_parent.right = successor.right

        return True
